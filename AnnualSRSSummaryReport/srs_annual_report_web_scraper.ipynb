# %% [markdown]
# waiting for elements to be available:
# https://stackoverflow.com/questions/59130200/selenium-wait-until-element-is-present-visible-and-interactable
#
# action chaining:
# https://www.selenium.dev/documentation/webdriver/actions_api/
#
# waiting:
# https://www.selenium.dev/documentation/webdriver/waits/
#
# select by visible text:
# https://stackoverflow.com/questions/7867537/how-to-select-a-drop-down-menu-value-with-selenium-using-python
#
# Sample html file for
# - Return A
# - County
# - Allegheny
# - Oct - 2024 - Oct 2025
#
# Some elements of a page are loaded and unloaded dynamically - like the options lists for report types and counties. Clicking inside the box loads an html object of ocunties, clicking outside hides it. This is not captured when doing a Save As html from the page.
# Inspecting the page using browser dev tools while it's loaded, copying the HTML from the inspector will grab the options list.
#
# The SSRS Report Viewer loads inside an iframe, the iframe html doesn't get saved when you right click a page and save the HTML - have to inspect the page manually with browser devtools, locate the iframe, and copy out the innerhtml. (Did this and added it to the sample html file to simulate what selenium sees during a session).
# - working with iframes: https://www.selenium.dev/documentation/webdriver/interactions/frames/

# %%
### Imports & static constants setup - this section shouldn't need changed much at all...
import os 
from datetime import datetime as dt 
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select

### Set some static lists to work with when choosing parameters 
### for reference / future - parameter options: 
report_by_options = ['County','Agency','Tag']
report_type_options = [
    'Law Enforcement Officers Killed or Assaulted',
    'Return A',
    'Supplemental Homicide',
    'Return of Arson Offenses',
    'Supplement Return A',
    'Human Trafficking',
    'ASRE Adult Arrests',
    'ASRE Adult Victims',
    'ASRE Juvenile Arrests',
    'ASRE Juvenile Victims',
    'Person Charged',
]
county_options = [
    '001 - Adams County',
    '002 - Allegheny County',
    '003 - Armstrong County',
    '004 - Beaver County',
    '005 - Bedford County',
    '006 - Berks County',
    '007 - Blair County',
    '008 - Bradford County',
    '009 - Bucks County',
    '010 - Butler County',
    '011 - Cambria County',
    '012 - Cameron County',
    '013 - Carbon County',
    '014 - Centre County',
    '015 - Chester County',
    '016 - Clarion County',
    '017 - Clearfield County',
    '018 - Clinton County',
    '019 - Columbia County',
    '020 - Crawford County',
    '021 - Cumberland County',
    '022 - Dauphin County',
    '023 - Delaware County',
    '024 - Elk County',
    '025 - Erie County',
    '026 - Fayette County',
    '027 - Forest County',
    '028 - Franklin County',
    '029 - Fulton County',
    '030 - Greene County',
    '031 - Huntingdon County',
    '032 - Indiana County',
    '033 - Jefferson County',
    '034 - Juniata County',
    '035 - Lackawanna County',
    '036 - Lancaster County',
    '037 - Lawrence County',
    '038 - Lebanon County',
    '039 - Lehigh County',
    '040 - Luzerne County',
    '041 - Lycoming County',
    '042 - McKean County',
    '043 - Mercer County',
    '044 - Mifflin County',
    '045 - Monroe County',
    '046 - Montgomery County',
    '047 - Montour County',
    '048 - Northampton County',
    '049 - Northumberland County',
    '050 - Perry County',
    '051 - Pike County',
    '052 - Potter County',
    '053 - Schuylkill County',
    '054 - Snyder County',
    '055 - Somerset County',
    '056 - Sullivan County',
    '057 - Susquehanna County',
    '058 - Tioga County',
    '059 - Union County',
    '060 - Venango County',
    '061 - Warren County',
    '062 - Washington County',
    '063 - Wayne County',
    '064 - Westmoreland County',
    '065 - Wyoming County',
    '066 - York County',
    '067 - Philadelphia County',
]

report_links = {
    "home" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/",
    "home" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Home/Index",
    "faq" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/FAQ/SearchResults?searchTerm=",

    "crime_in_pennsylvania" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/CrimePublication/CrimePublicationReports",
    "reports" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/ReportsIndex/List",
    "pccd_data_extracts" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/ExtractFile/ListPCCDExtractFiles",
    "crime_map" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/CrimeAnalytics/index.html",
    "ad-hoc_queries" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/AdvancedSearch/AdvancedSearch",
    "arrest_distribution_breakdown_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/ArrestDrillDown",
    "arrest_distribution_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/ArrestDistribution",
    "arrest_trends_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/ArrestTrends",
    "group_a_offense_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/GroupACrimeReport",
    "hate_crime_incidents_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/HateCrimeByORIReport",
    "leoka_incidents_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/LEOKAByORIReport",
    "murder_incidents_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/MurderCrimeByORIReport",
    "offense_and_arrest_summary_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/AgencySummaryReport",
    "offense_distribution_breakdown_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/DrillDownReports",
    "offense_distribution_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/CrimeDistributionReport",
    "offense_trends_comparison_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/CrimesIndex",
    "offense_trends_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/CrimeTrends",
    "annual_srs_summary_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/SRSReport/AnnualSRSSummary",
    "arrest_distribution_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/SRSReport/CrimeDistribution",
    "hate_crime_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/HateCrime",
    "offense_density_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/SRSReport/CrimeDensity",
    "offense_trends_comparison" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/SRSReport/CrimesIndex",
    "offense_trends_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/SRSReport/CrimeTrends",
    "ytd_comparison_report" : "https://www.ucr.pa.gov/PAUCRSPUBLIC/Report/UCRSummary",
}

# %%
########## SETUP FOR THIS RUN 
### Set download directory for exported report files: 
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
file_download_dir = r'/Users/danwelsh/Projects/CrimeData/PSP_UCR/SRSSummaryReport/MonthlyData'
chrome_options.add_experimental_option('prefs', {'download.default_directory': file_download_dir})

### set the actual parameters you want to use for this loop
report_url = report_links['annual_srs_summary_report']

report_type_selection = 'Return A'
report_by_selection = 'County'

### Time parameters
### for running individual months - unused right now
years = ['2025'] # ['2023','2024','2025']
### build list of Jan - Dec parameter tuples for years in years list 
calendar_year_parameters = [(f'Jan - {year}', f'Dec - {year}') for year in years]
###### ::: 2008 - 2024 captured already... 

months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Dec']
# build parameter option format as list of month - year combinations 
month_by_month_parameters = [(f'{month} - {year}', f'{month} - {year}') for year in years for month in months]

### define which time pd type you want to use
time_pd_parameters = calendar_year_parameters
time_pd_parameters = month_by_month_parameters

### subset counties if needed
counties = county_options

### build a list of dictionaries to use as parameters for the main loop
### srs summary - combination of counties and time periods 
parameters = [ 
    {'county':county, 'start': pd[0], 'end': pd[1]} for pd in time_pd_parameters for county in counties
]

### Parameter override for re-running failures from a previous run 
### (county time period dictionaries are logged if they fail, reload from the json file if needed)
import json 
if os.path.exists('LastRunFailures.json'):
    with open('LastRunFailures.json', 'r') as f:
        prev_failure_parameters = json.loads(f.read())
        # print(json.dumps(parameters, indent=2))
    for p in prev_failure_parameters:
        print(p)
    # print(prev_failure_parameters)
    ###check if file / prev_fail is empty; if empty use parameters above;  else retry failures
    if len(prev_failure_parameters) > 0:
        ## failures found, retry:
        parameters = prev_failure_parameters
    else:
        pass # parameters already set
    
print(dt.now().isoformat())
print(len(parameters), parameters)
# Out:
# 2025-10-18T11:01:50.162046
# 737 [{'county': '001 - Adams County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '002 - Allegheny County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '003 - Armstrong County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '004 - Beaver County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '005 - Bedford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '006 - Berks County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '007 - Blair County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '008 - Bradford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '009 - Bucks County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '010 - Butler County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '011 - Cambria County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '012 - Cameron County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '013 - Carbon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '014 - Centre County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '015 - Chester County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '016 - Clarion County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '017 - Clearfield County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '018 - Clinton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '019 - Columbia County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '020 - Crawford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '021 - Cumberland County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '022 - Dauphin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '023 - Delaware County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '024 - Elk County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '025 - Erie County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '026 - Fayette County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '027 - Forest County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '028 - Franklin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '029 - Fulton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '030 - Greene County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '031 - Huntingdon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '032 - Indiana County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '033 - Jefferson County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '034 - Juniata County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '035 - Lackawanna County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '036 - Lancaster County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '037 - Lawrence County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '038 - Lebanon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '039 - Lehigh County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '040 - Luzerne County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '041 - Lycoming County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '042 - McKean County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '043 - Mercer County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '044 - Mifflin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '045 - Monroe County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '046 - Montgomery County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '047 - Montour County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '048 - Northampton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '049 - Northumberland County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}, {'county': '050 - Perry County', 'start': 'Jan - 2025', 'end ...

# %%
### function definition - this gets executed once per loop for each parameter option
def export_iframe_report_to_excel(iframe_element):
    '''This can be re-used across multiple report types 
    Once the parameters have been selected and the report is generated on the page
    Find the iframe element in which the report is loaded
    pass that element here and it will wait for the report to fully load and trigger an excel export 
    '''
    ### switch context to iframe to find elements within it 
    driver.switch_to.frame(iframe_element.get_attribute('id'))
    if print_debug: print('waiting for report/export...', dt.now().isoformat())
    ### once iframe is loaded we can wait for elements within it
    # wait for report viewer to complete the report and show the export button 
    excel_export = WebDriverWait(driver, 30).until(EC.presence_of_element_located((By.XPATH,'//table[@title="Export drop down menu"]')))
    # wait for the copyright state of PA text to load at the bottom of the report - indicator loading is done, before exporting

    end_of_report_text = WebDriverWait(driver, 30).until(EC.visibility_of_element_located((By.XPATH, '//span[text()="© STATE OF Pennsylvania"]')))
    if print_debug: print('end of report visibility', dt.now())
    ### EXPORT: this is the onclick event for the excel export in the drop down, just exeucte this directly (after all loading is done:): 
    driver.execute_script("$find('rvSiteMapping').exportReport('EXCELOPENXML');")

def get_report_data(parameter):
    '''This is specific tot he SRSAnnual Summary report parameters
    '''
    # extract individual values from paremter dict
    county = parameter['county']
    start_pd = parameter['start']
    end_pd = parameter['end']
    # prep log record with start time 
    county_run = {
        'Start':start_pd,
        'County':county,
        'StartTime':dt.now().isoformat()
    }
    if print_debug: print('\n', start_pd, end_pd, county, dt.now(), end='...')
    
    # load page: 
    driver.get(report_url)

    if print_debug: print('getting elements...', dt.now().isoformat())
    ### find all of the relevant parameter objects on page (not all used, but at least validates they're all present as a test)
    start_month_year = driver.find_element(By.ID,'StartMonthYear') # date / text = set values from list 
    end_month_year = driver.find_element(By.ID, 'EndMonthYear') # date / text = set values from list 
    report_by = Select(driver.find_element(By.ID, 'ReportBy')) # option change "selected" value # SET BEFORE AGENCY
    chosen_choices = driver.find_element(By.CLASS_NAME, 'chosen-choices') # need to add one chosen choice (county) per loop 
    generate_report = driver.find_element(By.XPATH,'//*[@title="Generate Report"]')
    report_type = Select(driver.find_element(By.ID, 'SRSSummaryReportType'))
    county_input = driver.find_element(By.CLASS_NAME, 'chosen-choices')
    county_drop_down = driver.find_element(By.CLASS_NAME, 'chosen-results')

    if print_debug: print('setting report by and report type...', dt.now().isoformat())
    ### set report by and report type once: 
    sleep(3) # make sure page is loaded BEFORE changing report type to county...
    report_type.select_by_visible_text(report_type_selection)
    report_by.select_by_visible_text(report_by_selection) 
    sleep(2) # let county options load after changing report by value

    if print_debug: print('set year month parameters...', dt.now().isoformat())
    ### set year month parameters: 
    driver.execute_script(f"document.getElementsByName('StartMonthYear')[0].value= '{start_pd}'")
    driver.execute_script(f"document.getElementsByName('EndMonthYear')[0].value= '{end_pd}'")

    if print_debug: print('County Click and select...')
    ### click county box to load dropdown of choices
    ### if there is a previous choice - need to clear it...
    try:
        existing_county_choice = driver.find_element(By.CLASS_NAME, 'search-choice-close')
        existing_county_choice.click()
    except:
        # no existing county selection
        pass

    ### click input to load drop down selection. 
    county_input.click()
    sleep(1)
    ### get the element of the county one you want and simulate click (assumes county option list has loaded - will timeout if not)
    if print_debug: print('first try county...', dt.now().isoformat())
    county_choice = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, f"//li[contains(text(), '{county}')]")))
    county_choice.click()

    if print_debug: print('clicking generate...', dt.now().isoformat())
    ### run report: 
    generate_report.click()

    if print_debug: print('waiting for iframe...', dt.now().isoformat())
    ### wait for the iframe to load:
    iframe_element = WebDriverWait(driver, 30).until(EC.presence_of_element_located((By.ID, 'frmReport')))
    export_iframe_report_to_excel(iframe_element)

    end_time = dt.now().isoformat()
    if print_debug: print('exported and done', dt.now().isoformat())
    county_run['EndTime'] = end_time
    county_run['Status'] = 'Success'
    with open(log_file, 'a') as f:
        f.write(f',\n{json.dumps(county_run, indent=2)}')
    print('done.', end='')
print(dt.now().isoformat())
# Out:
# 2025-10-18T11:02:39.084814

# %%
### begin html session 
run_log = []
driver = webdriver.Chrome(options=chrome_options)
driver.implicitly_wait(5)
print(dt.now())
# Out:
# 2025-10-18 11:02:51.049487

# %%
#### MAIN DRIVER - 
# enables a bunch of print statements in the process, turn on if troubleshooting a single run - don't print this much in a big loop
print_debug = False 

start_time = dt.now().isoformat()
print(start_time)
log_file = 'RunLog_Annual.json'
fails = []
for n, parameter in enumerate(parameters):
    print(f'\n{n+1}/{len(parameters)} : {parameter}', dt.now().isoformat())
    
    try:
        get_report_data(parameter)
    except Exception as e:
        print(n, e)
        print('trying again...')
        try:
            get_report_data(parameter)
        except Exception as e:
            print(e)
            fails.append((parameter))
print(len(fails), fails)
with open('LastRunFailures.json', 'w') as f:
    f.write(json.dumps(fails, indent=2))
    print('failures logged')
# Out:
# 2025-10-18T11:03:07.112152
#
# 1/737 : {'county': '001 - Adams County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 2/737 : {'county': '002 - Allegheny County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 3/737 : {'county': '003 - Armstrong County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 4/737 : {'county': '004 - Beaver County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 5/737 : {'county': '005 - Bedford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 6/737 : {'county': '006 - Berks County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 7/737 : {'county': '007 - Blair County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 8/737 : {'county': '008 - Bradford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 9/737 : {'county': '009 - Bucks County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 10/737 : {'county': '010 - Butler County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 11/737 : {'county': '011 - Cambria County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 12/737 : {'county': '012 - Cameron County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 13/737 : {'county': '013 - Carbon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 14/737 : {'county': '014 - Centre County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 15/737 : {'county': '015 - Chester County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 16/737 : {'county': '016 - Clarion County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 17/737 : {'county': '017 - Clearfield County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 18/737 : {'county': '018 - Clinton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 19/737 : {'county': '019 - Columbia County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 20/737 : {'county': '020 - Crawford County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 21/737 : {'county': '021 - Cumberland County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 22/737 : {'county': '022 - Dauphin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 23/737 : {'county': '023 - Delaware County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 24/737 : {'county': '024 - Elk County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 25/737 : {'county': '025 - Erie County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 26/737 : {'county': '026 - Fayette County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 27/737 : {'county': '027 - Forest County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 28/737 : {'county': '028 - Franklin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 29/737 : {'county': '029 - Fulton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 30/737 : {'county': '030 - Greene County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 31/737 : {'county': '031 - Huntingdon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 32/737 : {'county': '032 - Indiana County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 33/737 : {'county': '033 - Jefferson County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 34/737 : {'county': '034 - Juniata County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 35/737 : {'county': '035 - Lackawanna County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 36/737 : {'county': '036 - Lancaster County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 37/737 : {'county': '037 - Lawrence County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 38/737 : {'county': '038 - Lebanon County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 39/737 : {'county': '039 - Lehigh County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 40/737 : {'county': '040 - Luzerne County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 41/737 : {'county': '041 - Lycoming County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 42/737 : {'county': '042 - McKean County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 43/737 : {'county': '043 - Mercer County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 44/737 : {'county': '044 - Mifflin County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 45/737 : {'county': '045 - Monroe County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 46/737 : {'county': '046 - Montgomery County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 47/737 : {'county': '047 - Montour County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 48/737 : {'county': '048 - Northampton County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 49/737 : {'county': '049 - Northumberland County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 50/737 : {'county': '050 - Perry County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 51/737 : {'county': '051 - Pike County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 52/737 : {'county': '052 - Potter County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 53/737 : {'county': '053 - Schuylkill County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 54/737 : {'county': '054 - Snyder County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 55/737 : {'county': '055 - Somerset County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 56/737 : {'county': '056 - Sullivan County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 57/737 : {'county': '057 - Susquehanna County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 58/737 : {'county': '058 - Tioga County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 59/737 : {'county': '059 - Union County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 60/737 : {'county': '060 - Venango County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 61/737 : {'county': '061 - Warren County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 62/737 : {'county': '062 - Washington County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 63/737 : {'county': '063 - Wayne County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 64/737 : {'county': '064 - Westmoreland County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 65/737 : {'county': '065 - Wyoming County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 66/737 : {'county': '066 - York County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 67/737 : {'county': '067 - Philadelphia County', 'start': 'Jan - 2025', 'end': 'Jan - 2025'}
# done.
# 68/737 : {'county': '001 - Adams County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 69/737 : {'county': '002 - Allegheny County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 70/737 : {'county': '003 - Armstrong County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 71/737 : {'county': '004 - Beaver County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 72/737 : {'county': '005 - Bedford County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 73/737 : {'county': '006 - Berks County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 74/737 : {'county': '007 - Blair County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 75/737 : {'county': '008 - Bradford County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 76/737 : {'county': '009 - Bucks County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 77/737 : {'county': '010 - Butler County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 78/737 : {'county': '011 - Cambria County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 79/737 : {'county': '012 - Cameron County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 80/737 : {'county': '013 - Carbon County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 81/737 : {'county': '014 - Centre County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 82/737 : {'county': '015 - Chester County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 83/737 : {'county': '016 - Clarion County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 84/737 : {'county': '017 - Clearfield County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 85/737 : {'county': '018 - Clinton County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 86/737 : {'county': '019 - Columbia County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 87/737 : {'county': '020 - Crawford County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# 86 Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104b9f5f0 cxxbridge1$str$ptr + 2894960
# 1   chromedriver                        0x0000000104b9752c cxxbridge1$str$ptr + 2861996
# 2   chromedriver                        0x00000001046bd5ec _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74324
# 3   chromedriver                        0x0000000104704fb4 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 367644
# 4   chromedriver                        0x0000000104746458 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 635072
# 5   chromedriver                        0x00000001046f9178 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318944
# 6   chromedriver                        0x0000000104b6333c cxxbridge1$str$ptr + 2648508
# 7   chromedriver                        0x0000000104b66918 cxxbridge1$str$ptr + 2662296
# 8   chromedriver                        0x0000000104b43dbc cxxbridge1$str$ptr + 2520124
# 9   chromedriver                        0x0000000104b67200 cxxbridge1$str$ptr + 2664576
# 10  chromedriver                        0x0000000104b3552c cxxbridge1$str$ptr + 2460588
# 11  chromedriver                        0x0000000104b86bec cxxbridge1$str$ptr + 2794092
# 12  chromedriver                        0x0000000104b86d70 cxxbridge1$str$ptr + 2794480
# 13  chromedriver                        0x0000000104b97178 cxxbridge1$str$ptr + 2861048
# 14  libsystem_pthread.dylib             0x00000001951a0c08 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000019519bba8 thread_start + 8
#
# trying again...
# done.
# 88/737 : {'county': '021 - Cumberland County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 89/737 : {'county': '022 - Dauphin County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 90/737 : {'county': '023 - Delaware County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 91/737 : {'county': '024 - Elk County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 92/737 : {'county': '025 - Erie County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 93/737 : {'county': '026 - Fayette County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 94/737 : {'county': '027 - Forest County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 95/737 : {'county': '028 - Franklin County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 96/737 : {'county': '029 - Fulton County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 97/737 : {'county': '030 - Greene County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 98/737 : {'county': '031 - Huntingdon County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 99/737 : {'county': '032 - Indiana County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 100/737 : {'county': '033 - Jefferson County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 101/737 : {'county': '034 - Juniata County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 102/737 : {'county': '035 - Lackawanna County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 103/737 : {'county': '036 - Lancaster County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 104/737 : {'county': '037 - Lawrence County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 105/737 : {'county': '038 - Lebanon County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 106/737 : {'county': '039 - Lehigh County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 107/737 : {'county': '040 - Luzerne County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 108/737 : {'county': '041 - Lycoming County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 109/737 : {'county': '042 - McKean County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 110/737 : {'county': '043 - Mercer County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 111/737 : {'county': '044 - Mifflin County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 112/737 : {'county': '045 - Monroe County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 113/737 : {'county': '046 - Montgomery County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 114/737 : {'county': '047 - Montour County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 115/737 : {'county': '048 - Northampton County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 116/737 : {'county': '049 - Northumberland County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 117/737 : {'county': '050 - Perry County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 118/737 : {'county': '051 - Pike County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 119/737 : {'county': '052 - Potter County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 120/737 : {'county': '053 - Schuylkill County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 121/737 : {'county': '054 - Snyder County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 122/737 : {'county': '055 - Somerset County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 123/737 : {'county': '056 - Sullivan County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 124/737 : {'county': '057 - Susquehanna County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 125/737 : {'county': '058 - Tioga County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 126/737 : {'county': '059 - Union County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 127/737 : {'county': '060 - Venango County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 128/737 : {'county': '061 - Warren County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 129/737 : {'county': '062 - Washington County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 130/737 : {'county': '063 - Wayne County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 131/737 : {'county': '064 - Westmoreland County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 132/737 : {'county': '065 - Wyoming County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 133/737 : {'county': '066 - York County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 134/737 : {'county': '067 - Philadelphia County', 'start': 'Feb - 2025', 'end': 'Feb - 2025'}
# done.
# 135/737 : {'county': '001 - Adams County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 136/737 : {'county': '002 - Allegheny County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 137/737 : {'county': '003 - Armstrong County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 138/737 : {'county': '004 - Beaver County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 139/737 : {'county': '005 - Bedford County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 140/737 : {'county': '006 - Berks County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 141/737 : {'county': '007 - Blair County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 142/737 : {'county': '008 - Bradford County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 143/737 : {'county': '009 - Bucks County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 144/737 : {'county': '010 - Butler County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 145/737 : {'county': '011 - Cambria County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 146/737 : {'county': '012 - Cameron County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 147/737 : {'county': '013 - Carbon County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 148/737 : {'county': '014 - Centre County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 149/737 : {'county': '015 - Chester County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 150/737 : {'county': '016 - Clarion County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 151/737 : {'county': '017 - Clearfield County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 152/737 : {'county': '018 - Clinton County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 153/737 : {'county': '019 - Columbia County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 154/737 : {'county': '020 - Crawford County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 155/737 : {'county': '021 - Cumberland County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 156/737 : {'county': '022 - Dauphin County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 157/737 : {'county': '023 - Delaware County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 158/737 : {'county': '024 - Elk County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 159/737 : {'county': '025 - Erie County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 160/737 : {'county': '026 - Fayette County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 161/737 : {'county': '027 - Forest County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 162/737 : {'county': '028 - Franklin County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 163/737 : {'county': '029 - Fulton County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 164/737 : {'county': '030 - Greene County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 165/737 : {'county': '031 - Huntingdon County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 166/737 : {'county': '032 - Indiana County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 167/737 : {'county': '033 - Jefferson County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 168/737 : {'county': '034 - Juniata County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 169/737 : {'county': '035 - Lackawanna County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 170/737 : {'county': '036 - Lancaster County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 171/737 : {'county': '037 - Lawrence County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 172/737 : {'county': '038 - Lebanon County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 173/737 : {'county': '039 - Lehigh County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 174/737 : {'county': '040 - Luzerne County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 175/737 : {'county': '041 - Lycoming County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 176/737 : {'county': '042 - McKean County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 177/737 : {'county': '043 - Mercer County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 178/737 : {'county': '044 - Mifflin County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 179/737 : {'county': '045 - Monroe County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 180/737 : {'county': '046 - Montgomery County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 181/737 : {'county': '047 - Montour County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 182/737 : {'county': '048 - Northampton County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 183/737 : {'county': '049 - Northumberland County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 184/737 : {'county': '050 - Perry County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 185/737 : {'county': '051 - Pike County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 186/737 : {'county': '052 - Potter County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 187/737 : {'county': '053 - Schuylkill County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 188/737 : {'county': '054 - Snyder County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 189/737 : {'county': '055 - Somerset County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 190/737 : {'county': '056 - Sullivan County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 191/737 : {'county': '057 - Susquehanna County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 192/737 : {'county': '058 - Tioga County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 193/737 : {'county': '059 - Union County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 194/737 : {'county': '060 - Venango County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 195/737 : {'county': '061 - Warren County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 196/737 : {'county': '062 - Washington County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 197/737 : {'county': '063 - Wayne County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 198/737 : {'county': '064 - Westmoreland County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 199/737 : {'county': '065 - Wyoming County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 200/737 : {'county': '066 - York County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 201/737 : {'county': '067 - Philadelphia County', 'start': 'Mar - 2025', 'end': 'Mar - 2025'}
# done.
# 202/737 : {'county': '001 - Adams County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 203/737 : {'county': '002 - Allegheny County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 204/737 : {'county': '003 - Armstrong County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 205/737 : {'county': '004 - Beaver County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 206/737 : {'county': '005 - Bedford County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 207/737 : {'county': '006 - Berks County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 208/737 : {'county': '007 - Blair County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 209/737 : {'county': '008 - Bradford County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 210/737 : {'county': '009 - Bucks County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 211/737 : {'county': '010 - Butler County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 212/737 : {'county': '011 - Cambria County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 213/737 : {'county': '012 - Cameron County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 214/737 : {'county': '013 - Carbon County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 215/737 : {'county': '014 - Centre County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 216/737 : {'county': '015 - Chester County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 217/737 : {'county': '016 - Clarion County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 218/737 : {'county': '017 - Clearfield County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 219/737 : {'county': '018 - Clinton County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 220/737 : {'county': '019 - Columbia County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 221/737 : {'county': '020 - Crawford County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 222/737 : {'county': '021 - Cumberland County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 223/737 : {'county': '022 - Dauphin County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 224/737 : {'county': '023 - Delaware County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 225/737 : {'county': '024 - Elk County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 226/737 : {'county': '025 - Erie County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 227/737 : {'county': '026 - Fayette County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 228/737 : {'county': '027 - Forest County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 229/737 : {'county': '028 - Franklin County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 230/737 : {'county': '029 - Fulton County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 231/737 : {'county': '030 - Greene County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 232/737 : {'county': '031 - Huntingdon County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 233/737 : {'county': '032 - Indiana County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 234/737 : {'county': '033 - Jefferson County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 235/737 : {'county': '034 - Juniata County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 236/737 : {'county': '035 - Lackawanna County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 237/737 : {'county': '036 - Lancaster County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 238/737 : {'county': '037 - Lawrence County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 239/737 : {'county': '038 - Lebanon County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 240/737 : {'county': '039 - Lehigh County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 241/737 : {'county': '040 - Luzerne County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 242/737 : {'county': '041 - Lycoming County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 243/737 : {'county': '042 - McKean County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 244/737 : {'county': '043 - Mercer County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 245/737 : {'county': '044 - Mifflin County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 246/737 : {'county': '045 - Monroe County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 247/737 : {'county': '046 - Montgomery County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 248/737 : {'county': '047 - Montour County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 249/737 : {'county': '048 - Northampton County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 250/737 : {'county': '049 - Northumberland County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 251/737 : {'county': '050 - Perry County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 252/737 : {'county': '051 - Pike County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 253/737 : {'county': '052 - Potter County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 254/737 : {'county': '053 - Schuylkill County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 255/737 : {'county': '054 - Snyder County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 256/737 : {'county': '055 - Somerset County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 257/737 : {'county': '056 - Sullivan County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 258/737 : {'county': '057 - Susquehanna County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 259/737 : {'county': '058 - Tioga County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 260/737 : {'county': '059 - Union County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 261/737 : {'county': '060 - Venango County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 262/737 : {'county': '061 - Warren County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 263/737 : {'county': '062 - Washington County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 264/737 : {'county': '063 - Wayne County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 265/737 : {'county': '064 - Westmoreland County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 266/737 : {'county': '065 - Wyoming County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 267/737 : {'county': '066 - York County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 268/737 : {'county': '067 - Philadelphia County', 'start': 'Apr - 2025', 'end': 'Apr - 2025'}
# done.
# 269/737 : {'county': '001 - Adams County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 270/737 : {'county': '002 - Allegheny County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 271/737 : {'county': '003 - Armstrong County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 272/737 : {'county': '004 - Beaver County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 273/737 : {'county': '005 - Bedford County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 274/737 : {'county': '006 - Berks County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 275/737 : {'county': '007 - Blair County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 276/737 : {'county': '008 - Bradford County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 277/737 : {'county': '009 - Bucks County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 278/737 : {'county': '010 - Butler County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 279/737 : {'county': '011 - Cambria County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 280/737 : {'county': '012 - Cameron County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 281/737 : {'county': '013 - Carbon County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 282/737 : {'county': '014 - Centre County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 283/737 : {'county': '015 - Chester County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 284/737 : {'county': '016 - Clarion County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 285/737 : {'county': '017 - Clearfield County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 286/737 : {'county': '018 - Clinton County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 287/737 : {'county': '019 - Columbia County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 288/737 : {'county': '020 - Crawford County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 289/737 : {'county': '021 - Cumberland County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 290/737 : {'county': '022 - Dauphin County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 291/737 : {'county': '023 - Delaware County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 292/737 : {'county': '024 - Elk County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 293/737 : {'county': '025 - Erie County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 294/737 : {'county': '026 - Fayette County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 295/737 : {'county': '027 - Forest County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 296/737 : {'county': '028 - Franklin County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 297/737 : {'county': '029 - Fulton County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 298/737 : {'county': '030 - Greene County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 299/737 : {'county': '031 - Huntingdon County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 300/737 : {'county': '032 - Indiana County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 301/737 : {'county': '033 - Jefferson County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 302/737 : {'county': '034 - Juniata County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 303/737 : {'county': '035 - Lackawanna County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 304/737 : {'county': '036 - Lancaster County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 305/737 : {'county': '037 - Lawrence County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 306/737 : {'county': '038 - Lebanon County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 307/737 : {'county': '039 - Lehigh County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 308/737 : {'county': '040 - Luzerne County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 309/737 : {'county': '041 - Lycoming County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 310/737 : {'county': '042 - McKean County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 311/737 : {'county': '043 - Mercer County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 312/737 : {'county': '044 - Mifflin County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 313/737 : {'county': '045 - Monroe County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 314/737 : {'county': '046 - Montgomery County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 315/737 : {'county': '047 - Montour County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 316/737 : {'county': '048 - Northampton County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 317/737 : {'county': '049 - Northumberland County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 318/737 : {'county': '050 - Perry County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 319/737 : {'county': '051 - Pike County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 320/737 : {'county': '052 - Potter County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 321/737 : {'county': '053 - Schuylkill County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 322/737 : {'county': '054 - Snyder County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 323/737 : {'county': '055 - Somerset County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 324/737 : {'county': '056 - Sullivan County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 325/737 : {'county': '057 - Susquehanna County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 326/737 : {'county': '058 - Tioga County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 327/737 : {'county': '059 - Union County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 328/737 : {'county': '060 - Venango County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 329/737 : {'county': '061 - Warren County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 330/737 : {'county': '062 - Washington County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 331/737 : {'county': '063 - Wayne County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 332/737 : {'county': '064 - Westmoreland County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 333/737 : {'county': '065 - Wyoming County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 334/737 : {'county': '066 - York County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 335/737 : {'county': '067 - Philadelphia County', 'start': 'May - 2025', 'end': 'May - 2025'}
# done.
# 336/737 : {'county': '001 - Adams County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 337/737 : {'county': '002 - Allegheny County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 338/737 : {'county': '003 - Armstrong County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 339/737 : {'county': '004 - Beaver County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 340/737 : {'county': '005 - Bedford County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 341/737 : {'county': '006 - Berks County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 342/737 : {'county': '007 - Blair County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 343/737 : {'county': '008 - Bradford County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 344/737 : {'county': '009 - Bucks County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 345/737 : {'county': '010 - Butler County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 346/737 : {'county': '011 - Cambria County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 347/737 : {'county': '012 - Cameron County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 348/737 : {'county': '013 - Carbon County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 349/737 : {'county': '014 - Centre County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 350/737 : {'county': '015 - Chester County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 351/737 : {'county': '016 - Clarion County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 352/737 : {'county': '017 - Clearfield County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 353/737 : {'county': '018 - Clinton County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 354/737 : {'county': '019 - Columbia County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 355/737 : {'county': '020 - Crawford County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 356/737 : {'county': '021 - Cumberland County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 357/737 : {'county': '022 - Dauphin County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 358/737 : {'county': '023 - Delaware County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 359/737 : {'county': '024 - Elk County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 360/737 : {'county': '025 - Erie County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 361/737 : {'county': '026 - Fayette County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 362/737 : {'county': '027 - Forest County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 363/737 : {'county': '028 - Franklin County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 364/737 : {'county': '029 - Fulton County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 365/737 : {'county': '030 - Greene County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 366/737 : {'county': '031 - Huntingdon County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 367/737 : {'county': '032 - Indiana County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 368/737 : {'county': '033 - Jefferson County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 369/737 : {'county': '034 - Juniata County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 370/737 : {'county': '035 - Lackawanna County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 371/737 : {'county': '036 - Lancaster County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 372/737 : {'county': '037 - Lawrence County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 373/737 : {'county': '038 - Lebanon County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 374/737 : {'county': '039 - Lehigh County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 375/737 : {'county': '040 - Luzerne County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 376/737 : {'county': '041 - Lycoming County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 377/737 : {'county': '042 - McKean County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 378/737 : {'county': '043 - Mercer County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 379/737 : {'county': '044 - Mifflin County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 380/737 : {'county': '045 - Monroe County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 381/737 : {'county': '046 - Montgomery County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 382/737 : {'county': '047 - Montour County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 383/737 : {'county': '048 - Northampton County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 384/737 : {'county': '049 - Northumberland County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 385/737 : {'county': '050 - Perry County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 386/737 : {'county': '051 - Pike County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 387/737 : {'county': '052 - Potter County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 388/737 : {'county': '053 - Schuylkill County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 389/737 : {'county': '054 - Snyder County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 390/737 : {'county': '055 - Somerset County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 391/737 : {'county': '056 - Sullivan County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 392/737 : {'county': '057 - Susquehanna County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 393/737 : {'county': '058 - Tioga County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 394/737 : {'county': '059 - Union County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 395/737 : {'county': '060 - Venango County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 396/737 : {'county': '061 - Warren County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 397/737 : {'county': '062 - Washington County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 398/737 : {'county': '063 - Wayne County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 399/737 : {'county': '064 - Westmoreland County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 400/737 : {'county': '065 - Wyoming County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 401/737 : {'county': '066 - York County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 402/737 : {'county': '067 - Philadelphia County', 'start': 'Jun - 2025', 'end': 'Jun - 2025'}
# done.
# 403/737 : {'county': '001 - Adams County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 404/737 : {'county': '002 - Allegheny County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 405/737 : {'county': '003 - Armstrong County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 406/737 : {'county': '004 - Beaver County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 407/737 : {'county': '005 - Bedford County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# 406 Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104b9f5f0 cxxbridge1$str$ptr + 2894960
# 1   chromedriver                        0x0000000104b9752c cxxbridge1$str$ptr + 2861996
# 2   chromedriver                        0x00000001046bd5ec _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74324
# 3   chromedriver                        0x0000000104704fb4 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 367644
# 4   chromedriver                        0x0000000104746458 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 635072
# 5   chromedriver                        0x00000001046f9178 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318944
# 6   chromedriver                        0x0000000104b6333c cxxbridge1$str$ptr + 2648508
# 7   chromedriver                        0x0000000104b66918 cxxbridge1$str$ptr + 2662296
# 8   chromedriver                        0x0000000104b43dbc cxxbridge1$str$ptr + 2520124
# 9   chromedriver                        0x0000000104b67200 cxxbridge1$str$ptr + 2664576
# 10  chromedriver                        0x0000000104b3552c cxxbridge1$str$ptr + 2460588
# 11  chromedriver                        0x0000000104b86bec cxxbridge1$str$ptr + 2794092
# 12  chromedriver                        0x0000000104b86d70 cxxbridge1$str$ptr + 2794480
# 13  chromedriver                        0x0000000104b97178 cxxbridge1$str$ptr + 2861048
# 14  libsystem_pthread.dylib             0x00000001951a0c08 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000019519bba8 thread_start + 8
#
# trying again...
# done.
# 408/737 : {'county': '006 - Berks County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 409/737 : {'county': '007 - Blair County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 410/737 : {'county': '008 - Bradford County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 411/737 : {'county': '009 - Bucks County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 412/737 : {'county': '010 - Butler County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 413/737 : {'county': '011 - Cambria County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 414/737 : {'county': '012 - Cameron County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 415/737 : {'county': '013 - Carbon County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 416/737 : {'county': '014 - Centre County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 417/737 : {'county': '015 - Chester County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 418/737 : {'county': '016 - Clarion County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 419/737 : {'county': '017 - Clearfield County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 420/737 : {'county': '018 - Clinton County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 421/737 : {'county': '019 - Columbia County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 422/737 : {'county': '020 - Crawford County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 423/737 : {'county': '021 - Cumberland County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 424/737 : {'county': '022 - Dauphin County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 425/737 : {'county': '023 - Delaware County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 426/737 : {'county': '024 - Elk County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 427/737 : {'county': '025 - Erie County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 428/737 : {'county': '026 - Fayette County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 429/737 : {'county': '027 - Forest County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 430/737 : {'county': '028 - Franklin County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 431/737 : {'county': '029 - Fulton County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 432/737 : {'county': '030 - Greene County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 433/737 : {'county': '031 - Huntingdon County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 434/737 : {'county': '032 - Indiana County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 435/737 : {'county': '033 - Jefferson County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 436/737 : {'county': '034 - Juniata County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 437/737 : {'county': '035 - Lackawanna County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 438/737 : {'county': '036 - Lancaster County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 439/737 : {'county': '037 - Lawrence County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 440/737 : {'county': '038 - Lebanon County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 441/737 : {'county': '039 - Lehigh County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 442/737 : {'county': '040 - Luzerne County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 443/737 : {'county': '041 - Lycoming County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 444/737 : {'county': '042 - McKean County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 445/737 : {'county': '043 - Mercer County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 446/737 : {'county': '044 - Mifflin County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 447/737 : {'county': '045 - Monroe County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 448/737 : {'county': '046 - Montgomery County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 449/737 : {'county': '047 - Montour County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 450/737 : {'county': '048 - Northampton County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 451/737 : {'county': '049 - Northumberland County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 452/737 : {'county': '050 - Perry County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 453/737 : {'county': '051 - Pike County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 454/737 : {'county': '052 - Potter County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 455/737 : {'county': '053 - Schuylkill County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 456/737 : {'county': '054 - Snyder County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 457/737 : {'county': '055 - Somerset County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 458/737 : {'county': '056 - Sullivan County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 459/737 : {'county': '057 - Susquehanna County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 460/737 : {'county': '058 - Tioga County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 461/737 : {'county': '059 - Union County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 462/737 : {'county': '060 - Venango County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 463/737 : {'county': '061 - Warren County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 464/737 : {'county': '062 - Washington County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 465/737 : {'county': '063 - Wayne County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 466/737 : {'county': '064 - Westmoreland County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 467/737 : {'county': '065 - Wyoming County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 468/737 : {'county': '066 - York County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 469/737 : {'county': '067 - Philadelphia County', 'start': 'Jul - 2025', 'end': 'Jul - 2025'}
# done.
# 470/737 : {'county': '001 - Adams County', 'start': 'Aug - 2025', 'end': 'Aug - 2025'}
# 469 Message:
# Stacktrace:
# ...
# 1   chromedriver                        0x0000000104b9752c cxxbridge1$str$ptr + 2861996
# 2   chromedriver                        0x00000001046bd5ec _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74324
# 3   chromedriver                        0x0000000104704fb4 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 367644
# 4   chromedriver                        0x0000000104746458 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 635072
# 5   chromedriver                        0x00000001046f9178 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318944
# 6   chromedriver                        0x0000000104b6333c cxxbridge1$str$ptr + 2648508
# 7   chromedriver                        0x0000000104b66918 cxxbridge1$str$ptr + 2662296
# 8   chromedriver                        0x0000000104b43dbc cxxbridge1$str$ptr + 2520124
# 9   chromedriver                        0x0000000104b67200 cxxbridge1$str$ptr + 2664576
# 10  chromedriver                        0x0000000104b3552c cxxbridge1$str$ptr + 2460588
# 11  chromedriver                        0x0000000104b86bec cxxbridge1$str$ptr + 2794092
# 12  chromedriver                        0x0000000104b86d70 cxxbridge1$str$ptr + 2794480
# 13  chromedriver                        0x0000000104b97178 cxxbridge1$str$ptr + 2861048
# 14  libsystem_pthread.dylib             0x00000001951a0c08 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000019519bba8 thread_start + 8
#
# trying again...
# done.
# 621/737 : {'county': '018 - Clinton County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 622/737 : {'county': '019 - Columbia County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 623/737 : {'county': '020 - Crawford County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 624/737 : {'county': '021 - Cumberland County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 625/737 : {'county': '022 - Dauphin County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 626/737 : {'county': '023 - Delaware County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 627/737 : {'county': '024 - Elk County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 628/737 : {'county': '025 - Erie County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 629/737 : {'county': '026 - Fayette County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# 628 Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104b9f5f0 cxxbridge1$str$ptr + 2894960
# 1   chromedriver                        0x0000000104b9752c cxxbridge1$str$ptr + 2861996
# 2   chromedriver                        0x00000001046bd5ec _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74324
# 3   chromedriver                        0x0000000104704fb4 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 367644
# 4   chromedriver                        0x0000000104746458 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 635072
# 5   chromedriver                        0x00000001046f9178 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318944
# 6   chromedriver                        0x0000000104b6333c cxxbridge1$str$ptr + 2648508
# 7   chromedriver                        0x0000000104b66918 cxxbridge1$str$ptr + 2662296
# 8   chromedriver                        0x0000000104b43dbc cxxbridge1$str$ptr + 2520124
# 9   chromedriver                        0x0000000104b67200 cxxbridge1$str$ptr + 2664576
# 10  chromedriver                        0x0000000104b3552c cxxbridge1$str$ptr + 2460588
# 11  chromedriver                        0x0000000104b86bec cxxbridge1$str$ptr + 2794092
# 12  chromedriver                        0x0000000104b86d70 cxxbridge1$str$ptr + 2794480
# 13  chromedriver                        0x0000000104b97178 cxxbridge1$str$ptr + 2861048
# 14  libsystem_pthread.dylib             0x00000001951a0c08 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000019519bba8 thread_start + 8
#
# trying again...
# done.
# 630/737 : {'county': '027 - Forest County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 631/737 : {'county': '028 - Franklin County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 632/737 : {'county': '029 - Fulton County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 633/737 : {'county': '030 - Greene County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 634/737 : {'county': '031 - Huntingdon County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 635/737 : {'county': '032 - Indiana County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 636/737 : {'county': '033 - Jefferson County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 637/737 : {'county': '034 - Juniata County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 638/737 : {'county': '035 - Lackawanna County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 639/737 : {'county': '036 - Lancaster County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 640/737 : {'county': '037 - Lawrence County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 641/737 : {'county': '038 - Lebanon County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 642/737 : {'county': '039 - Lehigh County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 643/737 : {'county': '040 - Luzerne County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 644/737 : {'county': '041 - Lycoming County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 645/737 : {'county': '042 - McKean County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 646/737 : {'county': '043 - Mercer County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 647/737 : {'county': '044 - Mifflin County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 648/737 : {'county': '045 - Monroe County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 649/737 : {'county': '046 - Montgomery County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 650/737 : {'county': '047 - Montour County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 651/737 : {'county': '048 - Northampton County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 652/737 : {'county': '049 - Northumberland County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 653/737 : {'county': '050 - Perry County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 654/737 : {'county': '051 - Pike County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 655/737 : {'county': '052 - Potter County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 656/737 : {'county': '053 - Schuylkill County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 657/737 : {'county': '054 - Snyder County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 658/737 : {'county': '055 - Somerset County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 659/737 : {'county': '056 - Sullivan County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 660/737 : {'county': '057 - Susquehanna County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 661/737 : {'county': '058 - Tioga County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 662/737 : {'county': '059 - Union County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 663/737 : {'county': '060 - Venango County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 664/737 : {'county': '061 - Warren County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 665/737 : {'county': '062 - Washington County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 666/737 : {'county': '063 - Wayne County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 667/737 : {'county': '064 - Westmoreland County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 668/737 : {'county': '065 - Wyoming County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 669/737 : {'county': '066 - York County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 670/737 : {'county': '067 - Philadelphia County', 'start': 'Oct - 2025', 'end': 'Oct - 2025'}
# done.
# 671/737 : {'county': '001 - Adams County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 672/737 : {'county': '002 - Allegheny County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 673/737 : {'county': '003 - Armstrong County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 674/737 : {'county': '004 - Beaver County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 675/737 : {'county': '005 - Bedford County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 676/737 : {'county': '006 - Berks County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# 675 Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104b9f5f0 cxxbridge1$str$ptr + 2894960
# 1   chromedriver                        0x0000000104b9752c cxxbridge1$str$ptr + 2861996
# 2   chromedriver                        0x00000001046bd5ec _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74324
# 3   chromedriver                        0x0000000104704fb4 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 367644
# 4   chromedriver                        0x0000000104746458 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 635072
# 5   chromedriver                        0x00000001046f9178 _RNvCs47EqcsrPRmA_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 318944
# 6   chromedriver                        0x0000000104b6333c cxxbridge1$str$ptr + 2648508
# 7   chromedriver                        0x0000000104b66918 cxxbridge1$str$ptr + 2662296
# 8   chromedriver                        0x0000000104b43dbc cxxbridge1$str$ptr + 2520124
# 9   chromedriver                        0x0000000104b67200 cxxbridge1$str$ptr + 2664576
# 10  chromedriver                        0x0000000104b3552c cxxbridge1$str$ptr + 2460588
# 11  chromedriver                        0x0000000104b86bec cxxbridge1$str$ptr + 2794092
# 12  chromedriver                        0x0000000104b86d70 cxxbridge1$str$ptr + 2794480
# 13  chromedriver                        0x0000000104b97178 cxxbridge1$str$ptr + 2861048
# 14  libsystem_pthread.dylib             0x00000001951a0c08 _pthread_start + 136
# 15  libsystem_pthread.dylib             0x000000019519bba8 thread_start + 8
#
# trying again...
# done.
# 677/737 : {'county': '007 - Blair County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 678/737 : {'county': '008 - Bradford County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 679/737 : {'county': '009 - Bucks County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 680/737 : {'county': '010 - Butler County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 681/737 : {'county': '011 - Cambria County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 682/737 : {'county': '012 - Cameron County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 683/737 : {'county': '013 - Carbon County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 684/737 : {'county': '014 - Centre County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 685/737 : {'county': '015 - Chester County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 686/737 : {'county': '016 - Clarion County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 687/737 : {'county': '017 - Clearfield County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 688/737 : {'county': '018 - Clinton County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 689/737 : {'county': '019 - Columbia County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 690/737 : {'county': '020 - Crawford County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 691/737 : {'county': '021 - Cumberland County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 692/737 : {'county': '022 - Dauphin County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 693/737 : {'county': '023 - Delaware County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 694/737 : {'county': '024 - Elk County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 695/737 : {'county': '025 - Erie County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 696/737 : {'county': '026 - Fayette County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 697/737 : {'county': '027 - Forest County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 698/737 : {'county': '028 - Franklin County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 699/737 : {'county': '029 - Fulton County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 700/737 : {'county': '030 - Greene County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 701/737 : {'county': '031 - Huntingdon County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 702/737 : {'county': '032 - Indiana County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 703/737 : {'county': '033 - Jefferson County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 704/737 : {'county': '034 - Juniata County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 705/737 : {'county': '035 - Lackawanna County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 706/737 : {'county': '036 - Lancaster County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# 705 Message:
#
# trying again...
# done.
# 707/737 : {'county': '037 - Lawrence County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 708/737 : {'county': '038 - Lebanon County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 709/737 : {'county': '039 - Lehigh County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 710/737 : {'county': '040 - Luzerne County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 711/737 : {'county': '041 - Lycoming County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 712/737 : {'county': '042 - McKean County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 713/737 : {'county': '043 - Mercer County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 714/737 : {'county': '044 - Mifflin County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 715/737 : {'county': '045 - Monroe County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 716/737 : {'county': '046 - Montgomery County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 717/737 : {'county': '047 - Montour County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 718/737 : {'county': '048 - Northampton County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 719/737 : {'county': '049 - Northumberland County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 720/737 : {'county': '050 - Perry County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 721/737 : {'county': '051 - Pike County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 722/737 : {'county': '052 - Potter County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 723/737 : {'county': '053 - Schuylkill County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 724/737 : {'county': '054 - Snyder County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 725/737 : {'county': '055 - Somerset County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 726/737 : {'county': '056 - Sullivan County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 727/737 : {'county': '057 - Susquehanna County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 728/737 : {'county': '058 - Tioga County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 729/737 : {'county': '059 - Union County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 730/737 : {'county': '060 - Venango County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 731/737 : {'county': '061 - Warren County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 732/737 : {'county': '062 - Washington County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 733/737 : {'county': '063 - Wayne County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 734/737 : {'county': '064 - Westmoreland County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 735/737 : {'county': '065 - Wyoming County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 736/737 : {'county': '066 - York County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.
# 737/737 : {'county': '067 - Philadelphia County', 'start': 'Dec - 2025', 'end': 'Dec - 2025'}
# done.0 []
# failures logged
